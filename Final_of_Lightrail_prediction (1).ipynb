# %% [markdown]
# ### IMPORTING THE DATA

# %%
import pandas as pd
from pmdarima import auto_arima
data=pd.read_csv('Light_Rail_Patronage.csv',parse_dates=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          630 non-null    object
#  1   MyWay         630 non-null    int64
#  2   Paper Ticket  630 non-null    int64
#  3   Total         630 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 19.8+ KB

# %% [markdown]
# ### SORTING THE DATES

# %%
x=[]
y=[]
z=[]
for i in data['Date'].str.split('/'):
        x.append(i[0])
        y.append(i[1])
        z.append(i[2])
d=pd.DataFrame([x,y,z])
d=d.T
s=[]
for i,j,k in zip(d[0],d[1],d[2]):
    s.append(pd.Timestamp(day=int(i),month=int(j),year=int(k)))
data['Date']=s
data=data.sort_values('Date')

# %% [markdown]
# ### PLOTTING THE TOTAL PATRONAGE

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,5))
plt.plot([i for i in range(0,630)],data['Total'])
plt.xlabel('DATES')
plt.ylabel('NO OF PATRONAGE')
# Out:
# Text(0, 0.5, 'NO OF PATRONAGE')

# %%
train=data['Total'][0:623]
test=data['Total'][623:630]

# %% [markdown]
# ### EXPONENTIAL SMOOTHING MODEL

# %%
from statsmodels.tsa.holtwinters import ExponentialSmoothing
model=ExponentialSmoothing(train,trend='add',seasonal='mul',seasonal_periods=7).fit()
exponential_predictions=model.forecast(7)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:579: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/holtwinters/model.py:429: FutureWarning: After 0.13 initialization must be handled at model creation
#   FutureWarning,
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/holtwinters/model.py:922: ConvergenceWarning: Optimization failed to converge. Check mle_retvals.
#   ConvergenceWarning,
# /usr/local/lib/python3.6/dist-packages/statsmodels/tsa/base/tsa_model.py:379: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %% [markdown]
# ### SOME PREPROCESS FOR ARIMA

# %% [markdown]
# ### CHECKING THE SEASONALITY AND TREND USING ETS DECOMPOSE[ERROR TREND SEASONALITY]

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
data=data[['Total','Date']]
data=data.set_index('Date')
data.index=pd.to_datetime(data.index)
data=data.asfreq('d')
data=data.fillna(method='bfill')
seasonal=seasonal_decompose(data,model='additive')
seasonal.plot();

# %% [markdown]
# ###PLOTTING ACF AND PACF PLOTS

# %%
from statsmodels.graphics.tsaplots import plot_acf,plot_pacf
plot_acf(data['Total']);
plot_pacf(data['Total']);

# %% [markdown]
# ### TEST FOR STATIONARITY [AUGMENT DICKEY-FULLER TEST]

# %%
from statsmodels.tsa.stattools import adfuller
adfuller(data['Total'])
# Out:
# (-2.105765191632386,
#  0.2422027172345419,
#  20,
#  610,
#  {'1%': -3.441115625417986,
#   '10%': -2.56929951625907,
#   '5%': -2.866289751785392},
#  10744.322551779887)

# %% [markdown]
# The p(0.173) > 0.05 so the Total patronage data is following non stationary

# %% [markdown]
# we can calculate arima parameters [p,d,q] by above plots and test.But we have another method auto arima to calculate a best parameters for us

# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### AUTO ARIMA

# %%
from pmdarima import auto_arima
ar=auto_arima(data['Total'],startp=0,startq=0,max_p=5,max_q=5,seasonal=True,trace=True,m=7)
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(2,1,2)(1,0,1)[7] intercept   : AIC=11270.931, Time=3.21 sec
#  ARIMA(0,1,0)(0,0,0)[7] intercept   : AIC=12111.141, Time=0.03 sec
#  ARIMA(1,1,0)(1,0,0)[7] intercept   : AIC=inf, Time=nan sec
#  ARIMA(0,1,1)(0,0,1)[7] intercept   : AIC=11718.682, Time=0.84 sec
#  ARIMA(0,1,0)(0,0,0)[7]             : AIC=12109.142, Time=0.03 sec
#  ARIMA(2,1,2)(0,0,1)[7] intercept   : AIC=11562.595, Time=2.91 sec
#  ARIMA(2,1,2)(1,0,0)[7] intercept   : AIC=11321.576, Time=2.71 sec
#  ARIMA(2,1,2)(2,0,1)[7] intercept   : AIC=11272.756, Time=5.51 sec
#  ARIMA(2,1,2)(1,0,2)[7] intercept   : AIC=11273.133, Time=5.55 sec
#  ARIMA(2,1,2)(0,0,0)[7] intercept   : AIC=11723.381, Time=1.36 sec
#  ARIMA(2,1,2)(0,0,2)[7] intercept   : AIC=11459.337, Time=3.93 sec
#  ARIMA(2,1,2)(2,0,0)[7] intercept   : AIC=11234.681, Time=5.05 sec
#  ARIMA(1,1,2)(2,0,0)[7] intercept   : AIC=inf, Time=3.73 sec
#  ARIMA(2,1,1)(2,0,0)[7] intercept   : AIC=11233.690, Time=4.40 sec
#  ARIMA(2,1,1)(1,0,0)[7] intercept   : AIC=inf, Time=3.00 sec
#  ARIMA(2,1,1)(2,0,1)[7] intercept   : AIC=11267.226, Time=4.68 sec
#  ARIMA(2,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=nan sec
#  ARIMA(1,1,1)(2,0,0)[7] intercept   : AIC=11173.656, Time=3.26 sec
#  ARIMA(1,1,1)(1,0,0)[7] intercept   : AIC=11283.220, Time=2.45 sec
#  ARIMA(1,1,1)(2,0,1)[7] intercept   : AIC=11190.794, Time=4.34 sec
#  ARIMA(1,1,1)(1,0,1)[7] intercept   : AIC=inf, Time=nan sec
#  ARIMA(0,1,1)(2,0,0)[7] intercept   : AIC=11172.684, Time=3.36 sec
#  ARIMA(0,1,1)(1,0,0)[7] intercept   : AIC=11276.719, Time=1.51 sec
#  ARIMA(0,1,1)(2,0,1)[7] intercept   : AIC=11159.155, Time=4.10 sec
#  ARIMA(0,1,1)(1,0,1)[7] intercept   : AIC=11131.966, Time=2.50 sec
#  ARIMA(0,1,1)(1,0,2)[7] intercept   : AIC=11160.305, Time=4.47 sec
#  ARIMA(0,1,1)(0,0,0)[7] intercept   : AIC=12112.989, Time=0.07 sec
#  ARIMA(0,1,1)(0,0,2)[7] intercept   : AIC=11528.311, Time=2.23 sec
#  ARIMA(0,1,1)(2,0,2)[7] intercept   : AIC=inf, Time=4.33 sec
#  ARIMA(0,1,0)(1,0,1)[7] intercept   : AIC=11250.023, Time=2.12 sec
#  ARIMA(0,1,2)(1,0,1)[7] intercept   : AIC=11283.135, Time=2.64 sec
#  ARIMA(1,1,0)(1,0,1)[7] intercept   : AIC=11188.673, Time=2.47 sec
#  ARIMA(1,1,2)(1,0,1)[7] intercept   : AIC=11252.984, Time=3.25 sec
#  ARIMA(0,1,1)(1,0,1)[7]             : AIC=11126.771, Time=2.05 sec
#  ARIMA(0,1,1)(0,0,1)[7]             : AIC=11716.602, Time=0.69 sec
#  ARIMA(0,1,1)(1,0,0)[7]             : AIC=11274.835, Time=1.01 sec
#  ARIMA(0,1,1)(2,0,1)[7]             : AIC=inf, Time=3.20 sec
#  ARIMA(0,1,1)(1,0,2)[7]             : AIC=11125.620, Time=5.65 sec
#  ARIMA(0,1,1)(0,0,2)[7]             : AIC=11526.350, Time=1.91 sec
#  ARIMA(0,1,1)(2,0,2)[7]             : AIC=inf, Time=3.95 sec
#  ARIMA(0,1,0)(1,0,2)[7]             : AIC=11248.680, Time=0.65 sec
#  ARIMA(1,1,1)(1,0,2)[7]             : AIC=inf, Time=3.60 sec
#  ARIMA(0,1,2)(1,0,2)[7]             : AIC=11148.015, Time=3.81 sec
#  ARIMA(1,1,0)(1,0,2)[7]             : AIC=11182.656, Time=3.51 sec

# %%
ar.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                        SARIMAX Results
# ==============================================================================================
# Dep. Variable:                                      y   No. Observations:                  631
# Model:             SARIMAX(0, 1, 1)x(1, 0, [1, 2], 7)   Log Likelihood               -5557.810
# Date:                                Tue, 12 Jan 2021   AIC                          11125.620
# Time:                                        04:37:31   BIC                          11147.849
# Sample:                                             0   HQIC                         11134.254
#                                                 - 631
# Covariance Type:                                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.5672      0.021    -26.394      0.000      -0.609      -0.525
# ar.S.L7        0.9888      0.004    225.822      0.000       0.980       0.997
# ma.S.L7       -0.6422      0.023    -28.062      0.000      -0.687      -0.597
# ma.S.L14      -0.0811      0.025     -3.200      0.001      -0.131      -0.031
# sigma2      2.638e+06   7.44e+04     35.442      0.000    2.49e+06    2.78e+06
# ===================================================================================
# Ljung-Box (L1) (Q):                   4.00   Jarque-Bera (JB):              2665.29
# Prob(Q):                              0.05   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.35   Skew:                            -1.07
# Prob(H) (two-sided):                  0.00   Kurtosis:                        12.85
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %% [markdown]
# By above summary we can conclude that the best values  parameters [p,d,q]=[0,1,1]

# %% [markdown]
# ###ARIMA MODEL

# %%
from statsmodels.tsa.arima.model import ARIMA,ARIMAResults
model=ARIMA(train,order=(0,1,1)).fit()
start=len(train)
end=len(train)+len(test)-1
Arima_predictions=model.predict(start,end)

# %% [markdown]
# ###SARIMA MODEL [SEASONAL AUTO REGGRESSIVE INTEGRATED MOVING AVERAGE]

# %%
from statsmodels.tsa.statespace.sarimax import SARIMAX
model=SARIMAX(train,order=(0, 1, 1),seasonal_order=(1, 0, 2, 7)).fit()
Sarima_predictions=model.predict(start,end)

# %% [markdown]
# ###RECURREENT NEURAL NETWORK MODEL

# %% [markdown]
# PREPROCESSING

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
scaler=MinMaxScaler()
scaler.fit(np.array(train).reshape(-1,1))
x_train=scaler.transform(np.array(train).reshape(-1,1))
x_test=scaler.transform(np.array(test).reshape(-1,1))

n_inputs=7
n_features=1

gen=TimeseriesGenerator(x_train,x_train,length=n_inputs,batch_size=1)

# %% [markdown]
# CREATING THE RNN

# %%
model=Sequential()

model.add(LSTM(100,activation='relu'))

model.add(Dense(1))

model.compile('adam',loss='mse')

# %% [markdown]
# FITTING RNN

# %%
model.fit_generator(gen,epochs=25)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/25
# 616/616 [==============================] - 4s 4ms/step - loss: 0.0576
# Epoch 2/25
# 616/616 [==============================] - 3s 4ms/step - loss: 0.0247
# Epoch 3/25
# 616/616 [==============================] - 3s 4ms/step - loss: 0.0200
# Epoch 4/25
# 616/616 [==============================] - 3s 4ms/step - loss: 0.0178
# Epoch 5/25
# 616/616 [==============================] - 3s 4ms/step - loss: 0.0144
# Epoch 6/25
# 616/616 [==============================] - 3s 4ms/step - loss: 0.0164
# Epoch 7/25
# 616/616 [==============================] - 3s 4ms/step - loss: 0.0136
# Epoch 8/25
# 616/616 [==============================] - 2s 4ms/step - loss: 0.0131
# Epoch 9/25
# 616/616 [==============================] - 2s 4ms/step - loss: 0.0114
# Epoch 10/25
# 616/616 [==============================] - 3s 4ms/step - loss: 0.0104
# Epoch 11/25
# 616/616 [==============================] - 2s 4ms/step - loss: 0.0125
# Epoch 12/25
# 616/616 [==============================] - 2s 4ms/step - loss: 0.0130
# Epoch 13/25
# 616/616 [==============================] - 2s 4ms/step - loss: 0.0137
# Epoch 14/25
# 616/616 [==============================] - 2s 4ms/step - loss: 0.0114
# Epoch 15/25
# 616/616 [==============================] - 2s 4ms/step - loss: 0.0105
# Epoch 16/25
# 616/616 [==============================] - 2s 4ms/step - loss: 0.0123
# Epoch 17/25
# 616/616 [==============================] - 2s 4ms/step - loss: 0.0144
# Epoch 18/25
# 616/616 [==============================] - 3s 4ms/step - loss: 0.0110
# Epoch 19/25
# 616/616 [==============================] - 2s 4ms/step - loss: 0.0124
# Epoch 20/25
# 616/616 [==============================] - 3s 4ms/step - loss: 0.0117
# Epoch 21/25
# 616/616 [==============================] - 2s 4ms/step - loss: 0.0093
# Epoch 22/25
# 616/616 [==============================] - 2s 4ms/step - loss: 0.0105
# Epoch 23/25
# 616/616 [==============================] - 3s 4ms/step - loss: 0.0130
# Epoch 24/25
# 616/616 [==============================] - 3s 4ms/step - loss: 0.0121
# Epoch 25/25
# 616/616 [==============================] - 3s 4ms/step - loss: 0.0133

# %% [markdown]
# HERE 25 EPOCHS IS ENOUGH TO GET THE MINIMUM MEAN SQUARE ERROR SO NO NEED TO ADD MORE EPOCHS

# %% [markdown]
# PREDICTING THE TEST VALUES

# %%
test_predict=[]

train_to_pred=x_train[-7:].reshape((1,n_inputs,n_features))

for i in range(len(test)):
  new_pred=model.predict(train_to_pred)[0]

  test_predict.append(new_pred)

  train_to_pred=np.append(train_to_pred[:,1:,:],[[new_pred]],axis=1)
RNN_predictions=scaler.inverse_transform(test_predict)

# %%
Recurrent_predictions=[]
for i in RNN_predictions:
  Recurrent_predictions.append(i[0])

# %% [markdown]
# ###PLOTTING THE RESULTS

# %%
x=[i for i in range(7)]
plt.figure(figsize=(15,5))
plt.plot(x,test,label='ACTUAL TEST VALUES')
plt.plot(x,exponential_predictions,label='EXPONENTIAL PREDICTIONS')
plt.plot(x,Arima_predictions,label='ARIMA PREDICTIONS',color='k')
plt.plot(x,Sarima_predictions,label='SARIMA PREDICTIONS',color='y')
plt.plot(x,Recurrent_predictions,label='RNN PREDICTIONS',color='r')
plt.xlabel('DATE')
plt.ylabel('NO OF PATRONAGE')
plt.legend()

# %% [markdown]
# ### MODEL SELECTION

# %%
from statsmodels.tools.eval_measures import mse,rmse,meanabs
print('ROOT MEAN SQUARE ERRORS\nEXPONENTIAT SMOOTHING = {}\nARIMA MODEL = {}\nSARIMA MODEL = {}\nRNN MODEL = {}'.format(rmse(test,exponential_predictions),rmse(test,Arima_predictions),rmse(test,Sarima_predictions),rmse(test,Recurrent_predictions)))
# Out:
# ROOT MEAN SQUARE ERRORS
# EXPONENTIAT SMOOTHING = 2324.881837386394
# ARIMA MODEL = 1951.936449161316
# SARIMA MODEL = 2165.801428913735
# RNN MODEL = 2153.95926284896

# %%
def confidence_interval(s):
  m=np.mean(s)
  st=np.std(s)
  #z score for 95% CI is 1.96
  upper_limit=m+(1.96*(st/np.sqrt(len(s))))
  lower_limit=m+(1.96*(st/np.sqrt(len(s))))
  return (lower_limit,upper_limit)
aa=confidence_interval(exponential_predictions)
bb=confidence_interval(Arima_predictions)
cc=confidence_interval(Sarima_predictions)
dd=confidence_interval(Recurrent_predictions)
print('COFIDENCE INTERVALS\nEXPONENTIAT SMOOTHING = {}\nARIMA MODEL = {}\nSARIMA MODEL = {}\nRNN MODEL = {}'.format(aa,bb,cc,dd))
# Out:
# COFIDENCE INTERVALS
# EXPONENTIAT SMOOTHING = (5440.864353721416, 5440.864353721416)
# ARIMA MODEL = (6829.121567460556, 6829.121567460556)
# SARIMA MODEL = (6078.282178380277, 6078.282178380277)
# RNN MODEL = (6162.822763642475, 6162.822763642475)

# %% [markdown]
# ROOT MEAN SQUARE ERROR OF ARIMA MODEL IS LOWER THAN OTHER MODELS SO WE CONCLUDE THAT ARIMA IS BEST MODEL

# %% [markdown]
# SO NOW WE CAN PREDICT THE NEXT 7 DAYS PATRONAGE TOTAL

# %%
b_model=ARIMA(data['Total'],order=(0,1,1)).fit()
future_predictions=b_model.predict(631,637)
future_predictions
# Out:
# 2021-01-12    6176.701505
# 2021-01-13    6176.701505
# 2021-01-14    6176.701505
# 2021-01-15    6176.701505
# 2021-01-16    6176.701505
# 2021-01-17    6176.701505
# 2021-01-18    6176.701505
# Freq: D, Name: predicted_mean, dtype: float64

# %% [markdown]
# ### Above the prediction of future 7 days total no of patronages

# %%
import matplotlib.pyplot as plt
import datetime as dt
import matplotlib.dates as dates
plt.figure(figsize=(15,5))
left = dt.date(2021, 1, 5)
right = dt.date(2021, 1, 20)
dates1 =dates.date2num(list(pd.date_range(start='1/5/2021', end='1/11/2021')))
plt.plot_date(dates1, data['Total'][-7:],'-')
dates2 =dates.date2num(list(pd.date_range(start='1/12/2021', end='1/18/2021')))
plt.plot_date(dates2,future_predictions ,'r-')
plt.gca().xaxis.set_tick_params(rotation = 30)

# %% [markdown]
# ###FINAL RESULT

# %%
final=pd.DataFrame(future_predictions)
a=[int(i) for i in future_predictions]
final.rename(columns={'predicted_mean':'TOTAL PATRONAGE'},inplace=True)
final.index.name='DATES'
final['TOTAL PATRONAGE']=a
final
# Out:
#             TOTAL PATRONAGE
# DATES
# 2021-01-12             6176
# 2021-01-13             6176
# 2021-01-14             6176
# 2021-01-15             6176
# 2021-01-16             6176
# 2021-01-17             6176
# 2021-01-18             6176

# %% [markdown]
# ###SO WE CAN CONCLUDE THAT WE WILL EXPECT AVERAGE OF 6176 TOTAL PATRONAGE FOR FUTURE 7 DAYS

# %% [markdown]
# ###                         !!! THANK YOU !!!
